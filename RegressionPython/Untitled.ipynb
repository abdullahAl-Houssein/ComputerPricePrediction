# %%
import pandas as pd

# %%
df = pd.read_excel('priceComputers.xlsx')

# %%
df
# Out:
#     ComputerType  CORI   Generation  firstHardType firstHardSize  SizeRam  \
# 0         LENOVO      5           11           SSD        256 GB        8
# 1             HP      7           10           SSD        512 GB        4
# 2             HP      3            7           SSD        256 GB        4
# 3            MSI      5           12           SSD        512 GB       16
# 4           ASUS      7           11           SSD           1 T       16
# ..           ...    ...          ...           ...           ...      ...
# 171         DELL      7           12           SSD       512 GB         8
# 172          MSI      5           11           SSD        256 GB        8
# 173       LENOVO      7           12           SSD        512 GB       16
# 174         ASUS      5            8           SSD        256 GB        8
# 175           HP      5           12           SSD        256 GB        8
#
#     BatteryLife ScreenSize ScreenType GraphicCardType laptopCase  price  \
# ...
